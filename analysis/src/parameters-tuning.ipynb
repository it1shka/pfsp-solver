# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp

# %% [markdown]
# ## Genetic Algorithm. Tuning population size

# %%
population_size_easy = pd.DataFrame({
  100: [14369, 14104, 14320, 14414, 14097],
  250: [14380, 14376, 14377, 14532, 14294],
  500: [14585, 14536, 14457, 14441, 14581]
})

# %%
population_size_easy.mean()
# Out:
# 100    14260.8
# 250    14391.8
# 500    14520.0
# dtype: float64

# %%
population_size_easy.boxplot()
# Out:
# <Axes: >

# %%
population_size_easy_tournament = pd.DataFrame({
  100: [14246, 14101, 14266, 14164, 14333],
  250: [14353, 14361, 14230, 14453, 14266],
  500: [14346,14234, 14254, 14190, 14080],
})

# %%
population_size_easy_tournament.mean()
# Out:
# 100    14222.0
# 250    14332.6
# 500    14220.8
# dtype: float64

# %%
ax = population_size_easy_tournament.boxplot()
plt.show()

# %%
population_size_medium = pd.DataFrame({
  100: [335214, 332621, 336544, 332449, 335255],
  250: [337726, 338212, 342129, 342224, 345011],
  500: [343531, 338160, 339655, 349383, 345138],
})

# %%
population_size_medium.mean()
# Out:
# 100    334416.6
# 250    341060.4
# 500    343173.4
# dtype: float64

# %%
population_size_medium.boxplot()
plt.show()

# %%
population_size_hard_tournament = pd.DataFrame({
  100: [7320358,7342055, 7414152, 7324673, 7334327],
  250: [7449541,7436204, 7343636, 7410431, 7390998],
  500: [7491285, 7532760, 7533971, 7517140, 7565873],
})

# %%
population_size_hard_tournament.mean()
# Out:
# 100    7347113.0
# 250    7406162.0
# 500    7528205.8
# dtype: float64

# %%
population_size_hard_tournament.boxplot()
plt.show()

# %%
small_population_size_hard_tournament = pd.DataFrame({
  25: [7294038, 7275268, 7225546, 7278070, 7258406],
  50: [7334522, 7330641, 7247028, 7273131, 7880127],
  75: [7292762, 7283441, 7325346, 7348960, 7346594],
})

# %%
small_population_size_hard_tournament.mean()
# Out:
# 25    7266265.6
# 50    7413089.8
# 75    7319420.6
# dtype: float64

# %%
small_population_size_hard_tournament.boxplot()
plt.show()

# %% [markdown]
# ## Genetic Algorithm. Tuning Crossover probability

# %%
crossover_basic = pd.DataFrame({
  0.1: [14289, 14247, 14333, 14122, 14317],
  0.3: [14257, 14340, 14260, 14339, 14320],
  0.6: [14539, 14333, 14680, 14456, 14392]
})

# %%
crossover_basic.mean()
# Out:
# 0.1    14261.6
# 0.3    14303.2
# 0.6    14480.0
# dtype: float64

# %%
crossover_basic.boxplot()
plt.show()

# %%
crossover_medium = pd.DataFrame({
  0.1: [328928, 331752, 332514, 333509, 335657],
  0.3: [343137, 338241, 338278, 340284, 339232],
  0.6: [342220, 342078, 349539, 344787, 350936]
})

# %%
crossover_medium.mean()
# Out:
# 0.1    332472.0
# 0.3    339834.4
# 0.6    345912.0
# dtype: float64

# %%
crossover_medium.boxplot()
plt.show()

# %%
crossover_hard = pd.DataFrame({
  0.1: [7642205, 7605948, 7668587, 7612876, 7677922],
  0.3: [7685415, 7671707, 7718936, 7700906, 7690656],
  0.6: [7765931, 7775549, 7799879, 7806798, 7784498],
})

# %%
crossover_hard.mean()
# Out:
# 0.1    7641507.6
# 0.3    7693524.0
# 0.6    7786531.0
# dtype: float64

# %%
crossover_hard.boxplot()
plt.show()

# %% [markdown]
# ## Genetic Algorithm. Tuning Mutation probability

# %%
mutation_basic = pd.DataFrame({
  0.1: [14317, 14403, 14402, 14516, 14387],
  0.3: [14391, 14327, 14195, 14471, 14412],
  0.6: [14243, 14585, 14555, 14437, 14481],
})

# %%
mutation_basic.mean()
# Out:
# 0.1    14405.0
# 0.3    14359.2
# 0.6    14460.2
# dtype: float64

# %%
mutation_basic.boxplot()
plt.show()

# %%
mutation_medium = pd.DataFrame({
  0.1: [339563, 337394, 340373, 335487, 338106],
  0.3: [336222, 342619, 341486, 340684, 343842],
  0.6: [342500, 340583, 344863, 343945, 343482]
})

# %%
mutation_medium.mean()
# Out:
# 0.1    338184.6
# 0.3    340970.6
# 0.6    343074.6
# dtype: float64

# %%
mutation_medium.boxplot()
plt.show()

# %%
mutation_hard = pd.DataFrame({
  0.1: [7680379, 7688865, 7658955, 7712214, 7748791],
  0.3: [7794367, 7758370, 7767668, 7712418, 7750428],
  0.6: [7745058, 7765670, 7755679, 7770681, 7794305]
})

# %%
mutation_hard.mean()
# Out:
# 0.1    7697840.8
# 0.3    7756650.2
# 0.6    7766278.6
# dtype: float64

# %%
mutation_hard.boxplot()
plt.show()

# %% [markdown]
# ## Genetic Algorithm. Tuning Crossover type

# %%
crossover_type_basic = pd.DataFrame({
  'partially-matched': [14107, 14344, 14265, 14171, 14284],
  'cycle': [14256, 14352, 14146, 14243, 14220]
})

# %%
crossover_type_basic.mean()
# Out:
# partially-matched    14234.2
# cycle                14243.4
# dtype: float64

# %%
crossover_type_medium = pd.DataFrame({
  'partially-matched': [334932, 336015, 337870, 335635, 336288],
  'cycle': [339826, 337654, 331043, 337863, 336666]
})

# %%
crossover_type_medium.mean()
# Out:
# partially-matched    336148.0
# cycle                336610.4
# dtype: float64

# %%
crossover_type_hard = pd.DataFrame({
  'partially-matched': [7643928, 7662129, 7579035, 7647691, 7682997],
  'cycle': [7562807, 7685930, 7685705, 7668278, 7707842]
})

# %%
crossover_type_hard.mean()
# Out:
# partially-matched    7643156.0
# cycle                7662112.4
# dtype: float64

# %% [markdown]
# ## Genetic Algorithm. Tuning Mutation type

# %%
mutation_type_basic = pd.DataFrame({
  'swap': [14345, 14648, 14404, 14326, 14162],
  'inversion': [14146, 14355, 14303, 14117, 14448],
})

# %%
mutation_type_basic.mean()
# Out:
# swap         14377.0
# inversion    14273.8
# dtype: float64

# %%
mutation_type_medium = pd.DataFrame({
  'swap': [339731, 340067, 341614, 336177, 332919],
  'inversion': [345714, 342068, 334559, 341548, 339844]
})

# %%
mutation_type_medium.mean()
# Out:
# swap         338101.6
# inversion    340746.6
# dtype: float64

# %%
mutation_type_hard = pd.DataFrame({
  'swap': [7691136, 7691963, 7699420, 7703804, 7714752],
  'inversion': [7701574, 7737653, 7756638, 7713553, 7678681]
})

# %%
mutation_type_hard.mean()
# Out:
# swap         7700215.0
# inversion    7717619.8
# dtype: float64

# %% [markdown]
# ## Simulated Annealing. Tuning Mutation type

# %%
sa_mutation_type_basic = pd.DataFrame({
  'swap': [14366, 14173, 14122, 14202, 14313],
  'inversion': [14848, 14708, 14207, 14325, 14326]
})

# %%
sa_mutation_type_basic.mean()
# Out:
# swap         14235.2
# inversion    14482.8
# dtype: float64

# %%
sa_mutation_type_basic.boxplot()
plt.show()

# %%
sa_mutation_type_medium = pd.DataFrame({
  'swap': [311057, 311805, 311133, 311892, 312425],
  'inversion': [330515, 327426, 330772, 322610, 328650]
})

# %%
sa_mutation_type_medium.mean()
# Out:
# swap         311662.4
# inversion    327994.6
# dtype: float64

# %%
sa_mutation_type_medium.boxplot()
plt.show()

# %%
sa_mutation_type_hard = pd.DataFrame({
  'swap': [7230904, 7187419, 7184987, 7211023, 7210024],
  'inversion': [7733691, 7634641, 7677106, 7705513, 7633523]
})

# %%
sa_mutation_type_hard.mean()
# Out:
# swap         7204871.4
# inversion    7676894.8
# dtype: float64

# %%
sa_mutation_type_hard.boxplot()
plt.show()

# %% [markdown]
# ## Simulated Annealing. Tuning Delay

# %%
sa_avg_delay_basic = np.array([15212, 15127, 15273, 14858, 15147]).mean()
sa_avg_delay_basic
# Out:
# np.float64(15123.4)

# %%
sa_avg_delay_medium = np.array([313080, 315247, 314484, 319523, 316402]).mean()
sa_avg_delay_medium
# Out:
# np.float64(315747.2)

# %%
sa_avg_delay_hard = np.array([7224021, 7156633, 7181688, 7200920, 7200920]).mean()
sa_avg_delay_hard
# Out:
# np.float64(7192836.4)
