# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp

# %% [markdown]
# ## Algorithm Comparison. Basic problems

# %%
tai20_5_0 = pd.DataFrame({
  'GA': [14267, 14260, 14149, 14312, 14242, 14034, 14121, 14315, 14157, 14155],
  'SA': [14129, 14333, 14204, 14325, 14123, 14100, 14233, 14131, 14444, 14102],
  'RND': [15344, 15272, 15147, 15523, 15506, 15619, 15555, 15340, 15330, 15601]
})

# %%
tai20_5_0.mean()
# Out:
# GA     14201.2
# SA     14212.4
# RND    15423.7
# dtype: float64

# %%
tai20_5_0.min() - 14033
# Out:
# GA        1
# SA       67
# RND    1114
# dtype: int64

# %%
tai20_5_0.boxplot()
plt.show()

# %%
tai20_10_0 = pd.DataFrame({
  'GA': [21522, 21075, 21435, 21023, 21134, 21291, 21256, 21472, 21479, 21710],
  'SA': [21008, 21166, 21011, 21543, 21167, 21005, 21562, 21154, 21304, 21167],
  'RND': [23286, 23090, 23375, 23565, 23152, 23390, 23108, 23082, 23408, 23391]
})

# %%
tai20_10_0.mean()
# Out:
# GA     21339.7
# SA     21208.7
# RND    23284.7
# dtype: float64

# %%
tai20_10_0.min() - 20911
# Out:
# GA      112
# SA       94
# RND    2171
# dtype: int64

# %%
tai20_10_0.boxplot()
plt.show()

# %%
tai20_20_0 = pd.DataFrame({
  'GA': [34371, 34157, 34033, 34499, 34594, 34375, 34061, 34428, 34144, 34294],
  'SA': [34134, 34187, 34094, 34111, 34465, 33790, 33992, 34069, 34324, 34025],
  'RND': [35698, 36230, 36451, 35902, 35568, 36256, 36201, 36301, 35900, 35626]
})

# %%
tai20_20_0.mean()
# Out:
# GA     34295.6
# SA     34119.1
# RND    36013.3
# dtype: float64

# %%
tai20_20_0.min() - 33623
# Out:
# GA      410
# SA      167
# RND    1945
# dtype: int64

# %%
tai20_20_0.boxplot()
plt.show()

# %%
tai100_10_0 = pd.DataFrame({
  'GA': [319650, 318905, 318810, 321809, 318589, 315001, 315548, 313911, 319722, 318572],
  'SA': [317245, 313830, 314680, 314278, 316592, 315928, 315806, 313051, 315520, 314539],
  'RND': [364629, 365837, 365809, 363538, 359604, 361537, 362224, 359860, 362129, 365488]
})

# %%
tai100_10_0.mean()
# Out:
# GA     318051.7
# SA     315146.9
# RND    363065.5
# dtype: float64

# %%
tai100_10_0.min() - 300566
# Out:
# GA     13345
# SA     12485
# RND    59038
# dtype: int64

# %%
tai100_10_0.boxplot()
plt.show()

# %%
tai100_20_0 = pd.DataFrame({
  'GA': [434910, 388077, 390915, 388906, 394715, 388538, 391677, 387010, 392951, 388288],
  'SA': [391312, 390913, 392475, 392383, 393920, 386618, 392226, 388952, 386451, 390186],
  'RND': [442264, 439190, 440291, 439050, 440661, 442574, 442442, 437632, 443509, 444045]
})

# %%
tai100_20_0.mean()
# Out:
# GA     394598.7
# SA     390543.6
# RND    441165.8
# dtype: float64

# %%
tai100_20_0.min() - 367267
# Out:
# GA     19743
# SA     19184
# RND    70365
# dtype: int64

# %%
tai100_20_0.boxplot()
plt.show()

# %%
tai500_20_0 = pd.DataFrame({
  'GA': [7224508, 7231077, 7201938, 7282332, 7257079, 7267937, 7276140, 7212163, 7237210, 7209834],
  'SA': [7228127, 7176347, 7237133, 7236584, 7195708, 7194451, 7227302, 7197277, 7190040, 7202190],
  'RND': [7961604, 7946369, 7942077, 7958946, 7887685, 7942911, 7975489, 7942510, 7976829, 7959192]
})

# %%
tai500_20_0.mean()
# Out:
# GA     7240021.8
# SA     7208515.9
# RND    7949361.2
# dtype: float64

# %%
tai500_20_0.min() - 6687476
# Out:
# GA      514462
# SA      488871
# RND    1200209
# dtype: int64

# %%
tai500_20_0.boxplot()
plt.show()
